# %% [markdown]
# # Data Exploration - Analyze [Lending Club's Loan Data](https://www.kaggle.com/wendykan/lending-club-loan-data)

# %% [markdown]
# Find important features from the dataset using plots and statistics!

# %% [markdown]
# <h3> Import Libraries </h3>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('data/loan.csv', low_memory=False)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)

print(df.shape)
df.head()
# Out:
# (887379, 74)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1  1077430    1314167     2500.0       2500.0           2500.0   60 months
# 2  1077175    1313524     2400.0       2400.0           2400.0   36 months
# 3  1076863    1277178    10000.0      10000.0          10000.0   36 months
# 4  1075358    1311748     3000.0       3000.0           3000.0   60 months
#
#    int_rate  installment grade sub_grade                 emp_title emp_length  \
# 0     10.65       162.87     B        B2                       NaN  10+ years
# 1     15.27        59.83     C        C4                     Ryder   < 1 year
# 2     15.96        84.33     C        C5                       NaN  10+ years
# 3     13.49       339.31     C        C1       AIR RESOURCES BOARD  10+ years
# 4     12.69        67.79     B        B5  University Medical Group     1 year
#
# ...

# %% [markdown]
# <h3> Data Analysis/Exploration </h3>

# %% [markdown]
# <h4> Loan Amount (Applied for) vs. Funded Amount </h4>

# %%
fig, ax = plt.subplots(1,2, figsize=(16,5))

sns.distplot(df.loan_amnt, ax=ax[0], color='#69695b')
ax[0].set_title('Loan Amount Applied by the Borrower')
sns.distplot(df.funded_amnt, ax=ax[1])
ax[1].set_title('Loan Amount Funded by the Lender')
# Out:
# Text(0.5,1,u'Loan Amount Funded by the Lender')

# %% [markdown]
# <h4> Loan Amount (Applied for) Distribution  vs. Funded Amount Distribution

# %%
fig, ax = plt.subplots(1,2, figsize=(16,5))
sns.boxplot(y=df.loan_amnt, ax=ax[0], color='#69695b')
ax[0].set_title('Applied Loan Amount Distribution')
sns.boxplot(y=df.funded_amnt, ax=ax[1],)
ax[1].set_title('Funded Loan Amount Distribution')
print'Mean Loan Amount Applied:', df.loan_amnt.mean()
print'Mean Funded Amount:', df.funded_amnt.mean()
# Out:
# Mean Loan Amount Applied: 14755.2646051
# Mean Funded Amount: 14741.877625

# %% [markdown]
# <h4> Loan Grade Distribution </h4>

# %%
grade_counts = df.grade.value_counts()
ax = sns.barplot(grade_counts.index, grade_counts.values)
ax.set_title('Loan Grade Count')
# Out:
# Text(0.5,1,u'Loan Grade Count')

# %% [markdown]
# <h4> Loan Status Distribution </h4>

# %%
status_counts = df.loan_status.value_counts()
ax = sns.barplot(status_counts.index, status_counts.values)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_title('Loan Status Count')
# Out:
# Text(0.5,1,u'Loan Status Count')

# %% [markdown]
# <h4> Number of loans issued over 2007-2015 </h4>

# %%
years = pd.to_datetime(df.issue_d)
df['year'] = years.dt.year
yearwise_loans = df.year.value_counts()

plt.figure(figsize=(10,6))
ax = sns.barplot(yearwise_loans.index, yearwise_loans.values)
ax.set_title('Number of loans issued year-wise')
# Out:
# Text(0.5,1,u'Number of loans issued year-wise')

# %% [markdown]
# <h4> Mean loan amount issued over the years 2007-2015 </h4>

# %%
plt.figure(figsize=(10,6))
sns.barplot(df.year,df.loan_amnt)

# %% [markdown]
# <h4> Good loan vs. Bad loan </h4>

# %%
df['rating'] = np.where((df.loan_status != 'Current') & 
                        (df.loan_status != 'Fully Paid') & 
                        (df.loan_status != 'Does not meet the credit policy. Status:Fully Paid') &
                        (df.loan_status != 'Issued'),
                        'Bad Loan', 'Good Loan')

plt.figure(figsize=(8,8))
#df.rating.value_counts().plot.pie(explode = [0, 0.2], autopct='%1.2f%%', shadow = True, startangle = 7)
pd.value_counts(df.rating).plot.pie(explode = [0, 0.2], autopct='%1.2f%%', shadow = True, startangle = 75)

# %% [markdown]
# <h4> Year-wise correlation of loan amount and loan type </h4>

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=df.year, y=df.loan_amnt, hue=df.rating)

# %% [markdown]
# <h4> Mean loan amount issued in the period from 2007 to 2015, grouped by load grade </h4>

# %%
# Grouping the data by year and grade and mean loan amount
loan_amnt_by_year_grade = df.groupby(['year', 'grade']).loan_amnt.mean()
print(loan_amnt_by_year_grade)

cmap = plt.cm.coolwarm
plt.figure(figsize=(10,6))
ax = loan_amnt_by_year_grade.unstack().plot(colormap=cmap)
ax.set_title('Mean Loan Amount Issued, by Year and Loan Grade')
# Out:
# year  grade
# 2007  A         5015.384615
#       B         8337.755102
#       C         8275.709220
#       D         8005.555556
#       E         8138.250000
#       F        11850.961538
#       G        10847.857143
# 2008  A         6234.512579
#       B         9174.705387
#       C         8840.086207
#                    ...
# 2014  E        17171.415437
#       F        16760.143821
#       G        19750.964392
# 2015  A        14691.720870
#       B        14251.806455
#       C        14745.592285
#       D        15947.183739
#       E        18472.726622
#       F        20090.274524
#       G        20427.838025
# Name: loan_amnt, Length: 63, dtype: float64
# Text(0.5,1,u'Mean Loan Amount Issued, by Year and Loan Grade')

# %% [markdown]
# <h4> Mean interest rates in the period from 2007 to 2015, grouped by loan grade </h4>

# %%
# Grouping the data by year and grade and mean interest rate
int_rate_by_year_grade = df.groupby(['year','grade']).int_rate.mean()

cmap = plt.cm.coolwarm
plt.figure(figsize=(10,6))
ax = int_rate_by_year_grade.unstack().plot(colormap=cmap)
ax.set_title('Mean Interest Rates, by Year and Loan Grade')
# Out:
# Text(0.5,1,u'Mean Interest Rates, by Year and Loan Grade')

# %% [markdown]
# <h4> Interest rate distribution by loan grade </h4>

# %%
plt.figure(figsize=(20,10))
ax = sns.violinplot(x='grade', y='int_rate', data=df, 
                    palette=sns.color_palette('Set2'), 
                    order=['A','B','C','D','E','F','G'])
ax.set_title('Interest rate distribution by loan grade')
# Out:
# Text(0.5,1,u'Interest rate distribution by loan grade')

# %% [markdown]
# <h4> State-wise bad loan rates </h4>

# %%
statewise_badloan_dict = {}
for state in df['addr_state'].unique():
    values = df[state==df['addr_state']].rating.value_counts()
    
    statewise_badloan_dict[state] = round(float(values[1])/float(values[0])*100,2)

import operator
sorted_d = sorted(statewise_badloan_dict.items(), key=operator.itemgetter(1), reverse=True) 
x, y = zip(*sorted_d)
plt.figure(figsize=(16,8))
sns.barplot(x,y,color='grey')

# %% [markdown]
# <h4> Bad loan rates grouped by loan purpose </h4>

# %%
purpose_badloan_dict = {}
for purpose in df['purpose'].unique():
    values = df[purpose==df['purpose']].rating.value_counts()
    purpose_badloan_dict[purpose] = round(float(values[1])/float(values[0])*100,2)

import operator
sorted_d = sorted(purpose_badloan_dict.items(), key=operator.itemgetter(1), reverse=True)
x, y = zip(*sorted_d)
plt.figure(figsize=(16,8))
ax = sns.barplot(x,y, color='brown')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# Out:
# [Text(0,0,u'educational'),
#  Text(0,0,u'small_business'),
#  Text(0,0,u'renewable_energy'),
#  Text(0,0,u'wedding'),
#  Text(0,0,u'house'),
#  Text(0,0,u'moving'),
#  Text(0,0,u'other'),
#  Text(0,0,u'medical'),
#  Text(0,0,u'vacation'),
#  Text(0,0,u'debt_consolidation'),
#  Text(0,0,u'major_purchase'),
#  Text(0,0,u'home_improvement'),
#  Text(0,0,u'car'),
#  Text(0,0,u'credit_card')]

# %% [markdown]
# <h3> Exploration completed </h3>
